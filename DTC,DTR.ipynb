# %%
import pandas as pd
df=pd.read_csv("https://raw.githubusercontent.com/aniruddhachoudhury/Red-Wine-Quality/refs/heads/master/winequality-red.csv")

# %%
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
df['quality'].unique()
# Out:
# array([5, 6, 7, 4, 8, 3])

# %%
df['quality'].value_counts()
# Out:
# quality
# 5    681
# 6    638
# 7    199
# 4     53
# 8     18
# 3     10
# Name: count, dtype: int64

# %%
df.describe().T
# Out:
#                        count       mean        std      min      25%  \
# fixed acidity         1599.0   8.319637   1.741096  4.60000   7.1000
# volatile acidity      1599.0   0.527821   0.179060  0.12000   0.3900
# citric acid           1599.0   0.270976   0.194801  0.00000   0.0900
# residual sugar        1599.0   2.538806   1.409928  0.90000   1.9000
# chlorides             1599.0   0.087467   0.047065  0.01200   0.0700
# free sulfur dioxide   1599.0  15.874922  10.460157  1.00000   7.0000
# total sulfur dioxide  1599.0  46.467792  32.895324  6.00000  22.0000
# density               1599.0   0.996747   0.001887  0.99007   0.9956
# pH                    1599.0   3.311113   0.154386  2.74000   3.2100
# sulphates             1599.0   0.658149   0.169507  0.33000   0.5500
# alcohol               1599.0  10.422983   1.065668  8.40000   9.5000
# quality               1599.0   5.636023   0.807569  3.00000   5.0000
#
#                            50%        75%        max
# ...

# %%
print(df.duplicated())
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4        True
#         ...
# 1594    False
# 1595    False
# 1596     True
# 1597    False
# 1598    False
# Length: 1599, dtype: bool

# %%
print(df.duplicated().sum())
# Out:
# 240

# %%
df.drop_duplicates(inplace=True)

# %%
print(df.duplicated().sum())
# Out:
# 0

# %%
x=df.drop("quality",axis=1)
y=df['quality']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.33,random_state=101)

# %%
x_test.head()
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 678             8.3             0.780         0.10             2.6      0.081
# 1500            7.5             0.725         0.04             1.5      0.076
# 1457            7.6             0.490         0.33             1.9      0.074
# 1079            7.9             0.300         0.68             8.3      0.050
# 909             7.3             0.305         0.39             1.2      0.059
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 678                  45.0                  87.0  0.99830  3.48       0.53
# 1500                  8.0                  15.0  0.99508  3.26       0.53
# 1457                 27.0                  85.0  0.99706  3.41       0.58
# 1079                 37.5                 278.0  0.99316  3.01       0.51
# 909                   7.0                  11.0  0.99331  3.29       0.52
#
#       alcohol
# 678      10.0
# 1500      9.6
# ...

# %%
y_test.head(2)
# Out:
# 678     5
# 1500    5
# Name: quality, dtype: int64

# %%
from sklearn.tree import DecisionTreeClassifier
dtc=DecisionTreeClassifier()

# %%
dtc.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred=dtc.predict(x_test)

# %%
y_pred
# Out:
# array([5., 5., 5., 6., 6., 6., 6., 6., 5., 5., 5., 5., 5., 6., 6., 5., 6.,
#        4., 5., 6., 4., 6., 6., 5., 7., 5., 6., 7., 7., 5., 5., 5., 6., 6.,
#        6., 7., 6., 5., 6., 5., 7., 5., 5., 7., 6., 5., 6., 8., 4., 6., 5.,
#        6., 4., 5., 5., 6., 5., 7., 7., 7., 6., 5., 6., 6., 5., 6., 5., 6.,
#        6., 5., 5., 5., 6., 6., 6., 7., 6., 6., 6., 6., 6., 6., 5., 6., 6.,
#        5., 4., 6., 5., 5., 6., 7., 5., 6., 7., 7., 6., 6., 5., 6., 5., 8.,
#        5., 7., 5., 5., 5., 6., 5., 6., 6., 4., 5., 7., 5., 6., 6., 5., 6.,
#        5., 6., 5., 4., 6., 5., 5., 7., 5., 6., 5., 5., 6., 6., 6., 5., 6.,
#        5., 6., 6., 6., 5., 7., 6., 5., 6., 7., 6., 6., 6., 5., 6., 6., 4.,
#        5., 5., 5., 5., 5., 5., 5., 5., 6., 5., 5., 7., 6., 6., 6., 6., 5.,
#        4., 7., 7., 6., 6., 7., 7., 5., 6., 4., 7., 6., 5., 6., 6., 6., 6.,
#        6., 6., 5., 6., 7., 6., 6., 5., 6., 5., 6., 6., 6., 6., 7., 6., 7.,
# ...

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test,y_pred)
# Out:
# 0.5928030303030303

# %%
from sklearn import tree
import matplotlib.pyplot as plt
fig=plt.figure(figsize=(25,15))
tree.plot_tree(dtc,filled=True)
# Out:
# [Text(0.5491837629183071, 0.9772727272727273, 'x[10] <= 10.525\ngini = 0.638\nsamples = 1071\nvalue = [5, 33, 451, 439, 132, 11]'),
#  Text(0.3577256090059055, 0.9318181818181818, 'x[6] <= 95.5\ngini = 0.551\nsamples = 677\nvalue = [4.0, 22.0, 386.0, 236.0, 27.0, 2.0]'),
#  Text(0.45345468596210625, 0.9545454545454546, 'True  '),
#  Text(0.20560869832677164, 0.8863636363636364, 'x[9] <= 0.575\ngini = 0.577\nsamples = 579\nvalue = [4, 21, 298, 228, 26, 2]'),
#  Text(0.07726377952755906, 0.8409090909090909, 'x[10] <= 10.15\ngini = 0.487\nsamples = 210\nvalue = [1, 14, 140, 53, 2, 0]'),
#  Text(0.038385826771653545, 0.7954545454545454, 'x[8] <= 3.165\ngini = 0.444\nsamples = 181\nvalue = [1, 12, 129, 38, 1, 0]'),
#  Text(0.01968503937007874, 0.75, 'x[4] <= 0.071\ngini = 0.169\nsamples = 33\nvalue = [0, 1, 30, 2, 0, 0]'),
#  Text(0.015748031496062992, 0.7045454545454546, 'x[3] <= 3.4\ngini = 0.611\nsamples = 6\nvalue = [0, 1, 3, 2, 0, 0]'),
# ...

# %% [markdown]
# Decision tree Regressor

# %%
from sklearn.tree import DecisionTreeRegressor
dtr=DecisionTreeRegressor()

# %%
dtr.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor()

# %%
dtr_pred=dtr.predict(x_test)

# %%
dtr_pred
# Out:
# array([5., 5., 5., 6., 6., 6., 6., 6., 5., 5., 5., 5., 5., 6., 6., 5., 6.,
#        4., 5., 6., 4., 6., 6., 5., 7., 5., 6., 7., 7., 5., 5., 5., 6., 6.,
#        6., 7., 6., 5., 6., 5., 7., 5., 5., 7., 6., 5., 6., 8., 4., 6., 5.,
#        6., 4., 5., 5., 6., 5., 7., 7., 7., 6., 5., 6., 6., 5., 6., 5., 6.,
#        6., 5., 5., 5., 6., 6., 6., 7., 6., 6., 6., 6., 6., 6., 5., 6., 6.,
#        5., 4., 6., 5., 5., 6., 7., 5., 6., 7., 7., 6., 6., 5., 6., 5., 8.,
#        5., 7., 5., 5., 5., 6., 5., 6., 6., 4., 5., 7., 5., 6., 6., 5., 6.,
#        5., 6., 5., 4., 6., 5., 5., 7., 5., 6., 5., 5., 6., 6., 6., 5., 6.,
#        5., 6., 6., 6., 5., 7., 6., 5., 6., 7., 6., 6., 6., 5., 6., 6., 4.,
#        5., 5., 5., 5., 5., 5., 5., 5., 6., 5., 5., 7., 6., 6., 6., 6., 5.,
#        4., 7., 7., 6., 6., 7., 7., 5., 6., 4., 7., 6., 5., 6., 6., 6., 6.,
#        6., 6., 5., 6., 7., 6., 6., 5., 6., 5., 6., 6., 6., 6., 7., 6., 7.,
# ...

# %%
accuracy_score(y_test,dtr_pred)
# Out:
# 0.5587121212121212

# %%
fig=plt.figure(figsize=(20,13))
tree.plot_tree(dtr,filled=True,fontsize=9)
# Out:
# [Text(0.4981969061847296, 0.9772727272727273, 'x[10] <= 10.525\nsquared_error = 0.626\nsamples = 1071\nvalue = 5.647'),
#  Text(0.1931622041076816, 0.9318181818181818, 'x[1] <= 0.335\nsquared_error = 0.436\nsamples = 677\nvalue = 5.393'),
#  Text(0.34567955514620563, 0.9545454545454546, 'True  '),
#  Text(0.048735205384079834, 0.8863636363636364, 'x[9] <= 0.685\nsquared_error = 0.571\nsamples = 63\nvalue = 6.0'),
#  Text(0.014852634021814807, 0.8409090909090909, 'x[10] <= 9.4\nsquared_error = 0.336\nsamples = 23\nvalue = 5.478'),
#  Text(0.0074263170109074034, 0.7954545454545454, 'x[9] <= 0.515\nsquared_error = 0.16\nsamples = 5\nvalue = 4.8'),
#  Text(0.0037131585054537017, 0.75, 'squared_error = 0.0\nsamples = 1\nvalue = 4.0'),
#  Text(0.011139475516361104, 0.75, 'squared_error = 0.0\nsamples = 4\nvalue = 5.0'),
#  Text(0.02227895103272221, 0.7954545454545454, 'x[4] <= 0.089\nsquared_error = 0.222\nsamples = 18\nvalue = 5.667'),
# ...

# %%
# For increasing the accuracy we use some ensemble techniques

# %%
from sklearn.ensemble import RandomForestClassifier
Rf_model=RandomForestClassifier()

# %%
Rf_model.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
Rf_model.predict(x_test)
# Out:
# array([5, 5, 5, 6, 6, 6, 6, 6, 6, 5, 6, 5, 6, 6, 6, 5, 6, 5, 5, 6, 6, 5,
#        5, 5, 5, 5, 5, 6, 7, 5, 5, 5, 6, 5, 6, 6, 6, 6, 5, 5, 7, 5, 6, 6,
#        6, 6, 6, 6, 5, 6, 5, 6, 5, 6, 6, 6, 6, 8, 7, 7, 5, 5, 6, 5, 5, 5,
#        5, 6, 5, 5, 5, 6, 6, 6, 5, 7, 6, 6, 5, 7, 5, 6, 5, 6, 6, 5, 6, 6,
#        5, 5, 6, 6, 5, 5, 7, 6, 5, 6, 5, 6, 5, 6, 5, 7, 5, 6, 5, 6, 5, 6,
#        6, 6, 5, 7, 5, 6, 6, 5, 6, 5, 6, 5, 5, 7, 6, 5, 6, 5, 6, 6, 5, 5,
#        7, 6, 5, 7, 5, 6, 6, 7, 5, 6, 5, 5, 6, 6, 5, 6, 6, 5, 6, 6, 5, 6,
#        6, 5, 5, 5, 6, 5, 5, 6, 5, 5, 7, 6, 6, 7, 6, 5, 5, 6, 6, 5, 6, 6,
#        6, 6, 6, 5, 7, 6, 5, 5, 6, 6, 6, 6, 5, 5, 6, 6, 6, 6, 5, 6, 5, 6,
#        6, 6, 5, 6, 5, 7, 6, 5, 6, 6, 6, 6, 6, 5, 7, 5, 6, 7, 5, 6, 5, 5,
#        5, 7, 5, 6, 7, 6, 6, 6, 6, 6, 5, 6, 6, 5, 5, 5, 6, 5, 6, 5, 6, 6,
#        6, 5, 5, 5, 5, 6, 5, 5, 6, 6, 5, 5, 6, 6, 6, 5, 6, 6, 5, 7, 5, 5,
#        5, 5, 5, 5, 6, 7, 5, 6, 6, 5, 6, 5, 5, 6, 6, 5, 6, 6, 6, 7, 5, 6,
# ...

# %%
Rf_pred=Rf_model.predict(x_test)

# %%
accuracy_score(y_test,Rf_pred)       #Accuracy was increased
# Out:
# 0.6742424242424242

# %%
from sklearn.ensemble import BaggingClassifier
bgc=BaggingClassifier()

# %%
bgc.fit(x_train,y_train)
# Out:
# BaggingClassifier()

# %%
bgc_pred=bgc.predict(x_test)

# %%
accuracy_score(y_test,bgc_pred)
# Out:
# 0.6382575757575758
